# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# feedback="The generated answer is mostly accurate but contains a minor omission and potential confusion in naming. The reference answer clearly states that Maxine Thompson won the Insurellm Innovator of the Year (IIOTY) award in 2023. The generated answer identifies Maxine as a Senior Data Engineer and correctly states that she won the IIOTY award in 2023, but it does not specify her full name — 'Maxine' alone is insufficient to match the reference answer, which explicitly includes 'Maxine Thompson'.\n\n1. Accuracy: The core fact — Maxine won the IIOTY award in 2023 — is correct, and the award name is accurately interpreted (IIOTY = Insurellm Innovator of the Year). However, the lack of the full name 'Thompson' makes the factual precision incomplete. Since the reference answer specifies the full name, and the generated answer does not, this introduces a potential error in identifying the correct individual. Thus, the accuracy is not perfect.\n\n2. Completeness: The generated answer omits the full name 'Thompson', which is a key detail in the reference answer. A complete answer should include all identifying information provided in the reference. Therefore, this answer is incomplete in the sense that it fails to fully capture the referenced fact.\n\n3. Relevance: The answer directly addresses who won the award by naming Maxine and placing her in the role of winner. It focuses on the correct individual and award, so it is relevant and directly answers the question. No irrelevant information is added.\n\nOverall, the answer is factually sound in core elements but lacks critical detail (the full name), which diminishes its completeness and accuracy. While the main point is correct, it falls short of the reference in precision." accuracy=4.0 completeness=3.0 relevance=5.0
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/projects/llm_engineering/week5/evaluation/eval.py:164, in evaluate_answer(test)
#     162 judge_response = ollama.chat.completions.parse(model=MODEL, messages=judge_messages, response_format=AnswerEval)
#     163 print(judge_response.choices[0].message.parsed)
# --> 164 answer_eval = AnswerEval.model_validate_json(judge_response.choices[0].message.parsed)
#     166 return answer_eval, generated_answer, retrieved_docs
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/pydantic/main.py:746, in BaseModel.model_validate_json(cls, json_data, strict, context, by_alias, by_name)
#     740 if by_alias is False and by_name is not True:
#     741     raise PydanticUserError(
#     742         'At least one of `by_alias` or `by_name` must be set to True.',
#     743         code='validate-by-alias-and-name-false',
#     744     )
# --> 746 return cls.__pydantic_validator__.validate_json(
#     747     json_data, strict=strict, context=context, by_alias=by_alias, by_name=by_name
#     748 )
#
# ValidationError: 1 validation error for AnswerEval
#   JSON input should be string, bytes or bytearray [type=json_type, input_value=AnswerEval(feedback="The ...ness=3.0, relevance=5.0), input_type=AnswerEval]
#     For further information visit https://errors.pydantic.dev/2.11/v/json_type

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.
# 5.0
# 4.0
# 5.0
